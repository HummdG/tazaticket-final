# %% [markdown]
# # Full Itienry Workflow

# %% [markdown]
# 3 types of itineries:
# 1. One way: `LHE to DXB`
# 2. Return:  `LHE -> DXB` and `DXB -> LHE`
# 3. Mutli-Segment: `LHE -> KHI -> JED -> DXB` and `DXB -> DOH -> LHE`

# %% [markdown]
# ### OAuth

# %%
import requests
import os
import json
import time
import dotenv

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
url = "https://oauth.pp.travelport.com/oauth/oauth20/token"

# payload = 'grant_type=password&username=TP11590373&password=sY8QNHQR&client_id=pp-cRGXqAeBfsyzuK2L7ZM0T5WXM1TVdQPVZLgrNGYC&client_secret=d65bf3ca79b2f058d33be1516f410e35aef0439760f5d99087da26651d9de8a1&scope=openid'
payload = f'grant_type=password&username={os.getenv("TRAVELPORT_USERNAME")}&password={os.getenv("TRAVELPORT_PASSWORD")}&client_id={os.getenv("TRAVELPORT_CLIENT_ID")}&client_secret={os.getenv("TRAVELPORT_CLIENT_SECRET")}&scope=openid'
headers = {
  'Cache-Control': 'no-cache',
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Bearer eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwianRpIjoidGEydHNrbHJqMmpiIn0..HeTi_3RtNXIorYsWI6BENA.QVHggDgQeRGDHLcp0UrUwKjNCdhtv5KAZzr1uC3V5h_0szGbrbL6h58gTsV9t7SQPbK32GXFGAKGHxhUgeWDzLwXHABanrF4grYFz1uGxm0wgyTM6zqq-r-Hc-CLDd6zOxknFy0k1Ho5KLro9vlEfSWzVRaycQBvabBopKo8on9C67pCuA3sNyh-ls1IgTFhOXtj1i7r6LJWG0ADL2vgV_qi_ISd2SX-3A1H6RSSEE_bHEuJ4gIWiqSrpAuGbveiQmVUpXBGoIszad7TaPnxk_PGbDCbg8ucRq_P8CXQl4vgVdaiceJBt0iwBdGp3xzYWbtIhFOYDDlykUIfNBplqNOx9tCJrEcYFu0oKIwjuTKDFMOlsB1NmxUKIlqpqxBQgHYLHdqR0Yroq1QbGOTG5ctwRQy84LDn1hsEQrDouhUQ820QJ2qrHSJ3gFp5KNyVBxVy-wfLrcioaa2j1oqTn0SX2btYXNmhaRhtD0Grz_53tYiZ1_W5w5AHTJZaYZ8iQYQ_YBi6IQFc6Q_G0uPMsPSRzN9q6VfPZTkd35d_EoQDXRcTSzrDu-ycZ_H9cjKuRJVXhUmOE6VBWVQbxC2GDRzlrMxGAphHDHv7KfeZdhNpmFFI3ETZcOH0qPTys4zNNNK6k9S-EyGCd-sFkqrdSwtoNDCTxEKyC57jss8IRtSaJ39IMKIcL4PWDamrtNjZYMQrx0iNCGg2IIoLflNXvxt6EE_dIBDnaoaBQmnLMZm1mUJZc6VpE07AfpnwTUBcOA3tBadItkZxUHOMT1mdGyzn9ROMR_ozzb0KP3F2c-mJaza-DtntE6YZaqkw2pFhriJ7N4kJ0895X_v9oYiCuunpGtN0lPfImaQNBYmjY5eRj4Cst1Q48AcGLfIjZ8lfjAC2pHFRuB6
# %% [markdown]
# ## One Way:
#
# - `LHE -> DXB`
# - 1x Adult Passenger

# %%
num_passengers = 1
itinerary = [
    {
        "departure": "LHR", # no details found for LHE to DXB on travelport, changing.
        "arrival": "DXB",
        # "departure": "LHE", # no details found for LHE to DXB on travelport, changing.
        # "arrival": "DXB",
        "departureDate": "2025-12-20"
    }
]
passenger_type = "ADT"  # ADT for Adult, CHD for Child, INF for Infant

# %% [markdown]
# ### Search

# %%
search_headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Accept-Version': '11',
  'Content-Version': '11',
  'taxBreakDown': 'true',
   "Authorization": f"Bearer {token}",
}

# %%
search_dict = {
  "@type": "CatalogProductOfferingsQueryRequest",
  "CatalogProductOfferingsRequest": {
    "@type": "CatalogProductOfferingsRequestAir",
    "maxNumberOfUpsellsToReturn": 4,
    "contentSourceList": [
      "GDS"
    ],
    "PassengerCriteria": [
      {
        "@type": "PassengerCriteria",
        "number": num_passengers,
        "passengerTypeCode": passenger_type
      }
    ],
    "SearchCriteriaFlight": [
      {
        "@type": "SearchCriteriaFlight",
        "departureDate": itinerary[0]["departureDate"],
        "From": {
          "value": itinerary[0]["departure"]
        },
        "To": {
          "value": itinerary[0]["arrival"]
        }
      }
    ],
    "SearchModifiersAir": {
      "@type": "SearchModifiersAir",
      "CarrierPreference": [
        {
          "@type": "CarrierPreference",
          "preferenceType": "Preferred",
          "carriers": [
            # "AA"
            "EK"
          ]
        }
      ]
    }
  }
}

# %%
# url = f"{os.getenv('TRAVELPORT_BASE_URL')}/{os.getenv('TRAVELPORT_VERSION')}/air/catalog/search/catalogproductofferings"
# url = f"{os.getenv('TRAVELPORT_BASE_URL')}/{os.getenv('TRAVELPORT_VERSION')}/air/catalog/search/catalogproductofferings" # getting 404 error 
url = "https://api.pp.travelport.com/11/air/catalog/search/catalogproductofferings"

search_payload = json.dumps(search_dict)

response = requests.request("POST", url, headers=search_headers, data=search_payload)

print(response)

print(type(response))

print(response.text)

search_response_json = response.json()
print(type(search_response_json))
print(search_response_json)

#save in a json file
with open("search_response.json", "w") as json_file:
    json.dump(search_response_json, json_file)
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {"CatalogProductOfferingsResponse":{"@type":"CatalogProductOfferingsResponse","transactionId":"92c5503b-81fe-4aad-bc65-60e0d255493d","CatalogProductOfferings":{"@type":"CatalogProductOfferings","CatalogProductOffering":[{"@type":"CatalogProductOffering","sequence":1,"id":"o1","Departure":"LGW","Arrival":"DXB","Brand":[{"@type":"BrandID","BrandRef":"b0"},{"@type":"BrandID","BrandRef":"b1"},{"@type":"BrandID","BrandRef":"b2"},{"@type":"BrandID","BrandRef":"b3"},{"@type":"BrandID","BrandRef":"b4"},{"@type":"BrandID","BrandRef":"b5"},{"@type":"BrandID","BrandRef":"b6"},{"@type":"BrandID","BrandRef":"b7"},{"@type":"BrandID","BrandRef":"b8"}],"ProductBrandOptions":[{"@type":"ProductBrandOptions","flightRefs":["s8"],"ProductBrandOffering":[{"@type":"ProductBrandOffering","Brand":{"@type":"BrandID","BrandRef":"b0"},"Product":[{"@type":"ProductID","productRef":"p0"}],"TermsAndConditions":{"@type":"TermsAndConditionsID","termsAndConditionsRef":"T0"},"CombinabilityCode":["j1"],"BestCombinablePrice":{"@type":"BestCombinablePriceDetail","CurrencyCode":{"decimalPlace":2,"value":"EUR"},"Base":537,"TotalTaxes":223.12,"TotalFees":0,"TotalPrice":760.12,"PriceBreakdown":[{"@type":"PriceBreakdownAir","quantity":1,"requestedPassengerType":"ADT","Amount":{"@type":"Amount","CurrencyCode":{"decimalPlace":2,"value":"EUR"},"Base":537,"Taxes":{"@type":"TaxesDetail","TotalTaxes":223.12,"Tax":[{"taxCode":"GB","value":104},{"taxCode":"UB","value":26.66},{"taxCode":"ZR","value":1.17},{"taxCode":"YQ","value":91.29}]},"Fees":{"@type":"FeesDetail","TotalFees":0},"Total":760.12},"Surcharges":{"@type":"SurchargesDetail","approximateInd":true,"TotalSurcharges":90,"Surcharge":[{"currencyCode":"EUR","purpose":"Weekend Surcharge","decimalPlace":2,"value":23},{"currencyCode":"EUR","purpose":"Other","decimalPlace":2,"value":58},{"currencyCode":"EUR","purpose":"Other","decimalPlace":2,"value":9}]}}]},"ContentSource":"GDS"},{"@type":"ProductBrandOffering","Brand":{"@type":"BrandID","BrandRef":"b5"},"Product":[{"@type":"ProductID","productRef":"p2"}],"TermsAndConditions":{"@type":"TermsAndConditionsID","termsAndConditionsRef":"T1"},"CombinabilityCode":["j2"],"BestCombinablePrice":{"@type":"BestCombinablePriceDetail","CurrencyCode":{"decimalPlace":2,"value":"EUR"},"Base":882,"TotalTaxes":223.12,"TotalFees":0,"TotalPrice":1105.12,"PriceBreakdown":[{"@type":"PriceBreakdownAir","quantity":1,"requestedPassengerType":"ADT","Amount":{"@type":"Amount","CurrencyCode":{"decimalPlace":2,"value":"EUR"},"Base":882,"Taxes":{"@type":"TaxesDetail","TotalTaxes":223.12,"Tax":[{"taxCode":"GB","value":104},{"taxCode":"UB","value":26.66},{"taxCode":"ZR","value":1.17},{"taxCode":"YQ","value":91.29}]},"Fees":{"@type":"FeesDetail","TotalFees":0},"Total":1105.12},"Surcharges":{"@type":"SurchargesDetail","approximateInd":true,"TotalSurcharges":97,"Surcharge":[{"currencyCode":"EUR","purpose":"Weekend Surcharge","decimalPlace":2,"value":23},{"currencyCode":"EUR","purpose":"Other","decimalPlace":2,"value":58},{"currencyCode":"EUR","purpose":"Other","decimalPlace":2,"value":16}]}}]},"ContentSource":"GDS"},{"@type":"ProductBrandOffering","Brand":{"@type":"BrandID","BrandRef":"b6"},"Product":[{"@type":"ProductID","productRef":"p4"}],"TermsAndConditions":{"@type":"TermsAndConditionsID","termsAndConditionsRef":"T2"},"CombinabilityCode":["j3"],"BestCombinablePrice":{"@type":"BestCombinablePriceDetail","CurrencyCode":{"decimalPlace":2,"value":"EUR"},"Base":3398,"TotalTaxes":745.43,"TotalFees":0,"TotalPrice":4143.43,"PriceBreakdown":[{"@type":"PriceBreakdownAir","quantity":1,"requestedPassengerType":"ADT","Amount":{"@type":"Amount","CurrencyCode":{"decimalPlace":2,"value":"EUR"},"Base":3398,"Taxes":{"@type":"TaxesDetail","TotalTaxes":745.43,"Tax":[{"taxCode":"GB","value":249.6},{"taxCode":"UB","value":26.66},{"taxCode":"ZR","value":1.17},{"taxCode":"YQ","value":468}]},"Fees":{"@type":"FeesDetail","TotalFees":0},"Total":4143.43},"Surcharges":{"@type":"SurchargesDetail","approximateInd":true,"TotalSurcharges" ...
# <class 'dict'>
# {'CatalogProductOfferingsResponse': {'@type': 'CatalogProductOfferingsResponse', 'transactionId': '92c5503b-81fe-4aad-bc65-60e0d255493d', 'CatalogProductOfferings': {'@type': 'CatalogProductOfferings', 'CatalogProductOffering': [{'@type': 'CatalogProductOffering', 'sequence': 1, 'id': 'o1', 'Departure': 'LGW', 'Arrival': 'DXB', 'Brand': [{'@type': 'BrandID', 'BrandRef': 'b0'}, {'@type': 'BrandID', 'BrandRef': 'b1'}, {'@type': 'BrandID', 'BrandRef': 'b2'}, {'@type': 'BrandID', 'BrandRef': 'b3'}, {'@type': 'BrandID', 'BrandRef': 'b4'}, {'@type': 'BrandID', 'BrandRef': 'b5'}, {'@type': 'BrandID', 'BrandRef': 'b6'}, {'@type': 'BrandID', 'BrandRef': 'b7'}, {'@type': 'BrandID', 'BrandRef': 'b8'}], 'ProductBrandOptions': [{'@type': 'ProductBrandOptions', 'flightRefs': ['s8'], 'ProductBrandOffering': [{'@type': 'ProductBrandOffering', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b0'}, 'Product': [{'@type': 'ProductID', 'productRef': 'p0'}], 'TermsAndConditions': {'@type': 'TermsAndConditionsID', 'termsAndConditionsRef': 'T0'}, 'CombinabilityCode': ['j1'], 'BestCombinablePrice': {'@type': 'BestCombinablePriceDetail', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 537, 'TotalTaxes': 223.12, 'TotalFees': 0, 'TotalPrice': 760.12, 'PriceBreakdown': [{'@type': 'PriceBreakdownAir', 'quantity': 1, 'requestedPassengerType': 'ADT', 'Amount': {'@type': 'Amount', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 537, 'Taxes': {'@type': 'TaxesDetail', 'TotalTaxes': 223.12, 'Tax': [{'taxCode': 'GB', 'value': 104}, {'taxCode': 'UB', 'value': 26.66}, {'taxCode': 'ZR', 'value': 1.17}, {'taxCode': 'YQ', 'value': 91.29}]}, 'Fees': {'@type': 'FeesDetail', 'TotalFees': 0}, 'Total': 760.12}, 'Surcharges': {'@type': 'SurchargesDetail', 'approximateInd': True, 'TotalSurcharges': 90, 'Surcharge': [{'currencyCode': 'EUR', 'purpose': 'Weekend Surcharge', 'decimalPlace': 2, 'value': 23}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 58}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 9}]}}]}, 'ContentSource': 'GDS'}, {'@type': 'ProductBrandOffering', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b5'}, 'Product': [{'@type': 'ProductID', 'productRef': 'p2'}], 'TermsAndConditions': {'@type': 'TermsAndConditionsID', 'termsAndConditionsRef': 'T1'}, 'CombinabilityCode': ['j2'], 'BestCombinablePrice': {'@type': 'BestCombinablePriceDetail', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 882, 'TotalTaxes': 223.12, 'TotalFees': 0, 'TotalPrice': 1105.12, 'PriceBreakdown': [{'@type': 'PriceBreakdownAir', 'quantity': 1, 'requestedPassengerType': 'ADT', 'Amount': {'@type': 'Amount', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 882, 'Taxes': {'@type': 'TaxesDetail', 'TotalTaxes': 223.12, 'Tax': [{'taxCode': 'GB', 'value': 104}, {'taxCode': 'UB', 'value': 26.66}, {'taxCode': 'ZR', 'value': 1.17}, {'taxCode': 'YQ', 'value': 91.29}]}, 'Fees': {'@type': 'FeesDetail', 'TotalFees': 0}, 'Total': 1105.12}, 'Surcharges': {'@type': 'SurchargesDetail', 'approximateInd': True, 'TotalSurcharges': 97, 'Surcharge': [{'currencyCode': 'EUR', 'purpose': 'Weekend Surcharge', 'decimalPlace': 2, 'value': 23}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 58}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 16}]}}]}, 'ContentSource': 'GDS'}, {'@type': 'ProductBrandOffering', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b6'}, 'Product': [{'@type': 'ProductID', 'productRef': 'p4'}], 'TermsAndConditions': {'@type': 'TermsAndConditionsID', 'termsAndConditionsRef': 'T2'}, 'CombinabilityCode': ['j3'], 'BestCombinablePrice': {'@type': 'BestCombinablePriceDetail', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 3398, 'TotalTaxes': 745.43, 'TotalFees': 0, 'TotalPrice': 4143.43, 'PriceBreakdown': [{'@type': 'PriceBreakdownAir', 'quantity': 1, 'requestedPassengerType': 'ADT', 'Amount': {'@type': 'Amount', 'CurrencyCode': {'decimalPlace': 2, 'value':  ...

# %%
type(response)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(type(response))

# %% [markdown]
# ## Price

# %%
import requests
import json

# %%
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Accept-Version': '11',
  'Content-Version': '11'
}

# %%
# url = "https://{{baseURL}}/{{version}}/air/price/offers/buildfromproducts"
url = "https://api.pp.travelport.com/11/air/price/offers/buildfromproducts"

payload = json.dumps(
    {
  "@type": "OfferQueryBuildFromProducts",
  "BuildFromProductsRequest": {
    "@type": "BuildFromProductsRequestAir",
    "PassengerCriteria": [
      {
        "@type": "PassengerCriteria",
        "number": 1,
        "passengerTypeCode": "ADT"
      }
    ],
    "ProductCriteriaAir": [
      {
        "SpecificFlightCriteria": [
          {
            "flightNumber": "2755",
            "carrier": "AA",
            "departureDate": "2025-06-28",
            "departureTime": "06:49:00",
            "arrivalDate": "2025-06-28",
            "arrivalTime": "08:23:00",
            "from": itinerary[0]["departure"],
            "to": itinerary[0]["arrival"],
            "classOfService": "Y",
            "cabin": "Economy",
            "segmentSequence": 1,
            "brandTier": "4",
            "AvailabilitySourceCode": "Q",
            "ContentSource": "GDS"
          }
        ],
        "sequence": 1
      }
    ]
  },
  "validateInventoryInd": True
})



response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %% [markdown]
# ### Reservation

# %% [markdown]
# 1. initiate workbench

# %%
import requests
import json

# %%
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Content-Version': '11',
  'Authorization': f'Bearer {token}'
  }

# %%
url = "https://api.pp.travelport.com/11/air/book/session/reservationworkbench"

payload = json.dumps({
  "@type": "ReservationID",
  "ReservationID": {}
})

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"ReservationResponse":{"@type":"ReservationResponse","Reservation":{"@type":"Reservation","Identifier":{"authority":"Travelport","value":"6f12e493-6f3f-4102-a76b-1119dee61d8d"}}}}

# %%
tp = "48d77f94-2a5c-4eda-9349-57e1ef3a6b9e"

# %% [markdown]
# 2. Add Offer

# %%
import requests
import json

# %% [markdown]
# In our choice, we have corresponding Refernces:
#
# - offer: `o5`
# - brand: `b0`
# - flightRef: `s4`
# - product: `p36`
# - Terms&Cond: `T17`

# %%
# load json into a  dict
with open("search_response.json") as f:
    search_response = json.load(f)

# %% [markdown]
# Extracting Offer

# %%
print(search_response["CatalogProductOfferingsResponse"]["ReferenceList"][2])
# Out:
# {'@type': 'ReferenceListBrand', 'Brand': [{'@type': 'Brand', 'name': 'Business Saver', 'tier': 7, 'shelfNumbers': [], 'code': 'BSSAVER', 'id': 'b2', 'Identifier': {'value': '1837060'}, 'BrandAttribute': [{'@type': 'BrandAttribute', 'classification': 'Refund', 'inclusion': 'Chargeable', 'groupCode': 'BF', 'subGroupCode': 'RF', 'subCode': '056'}, {'@type': 'BrandAttribute', 'classification': 'Rebooking', 'inclusion': 'Chargeable', 'groupCode': 'BF', 'subGroupCode': 'VC', 'subCode': '059'}, {'@type': 'BrandAttribute', 'classification': 'Meals', 'inclusion': 'Included', 'groupCode': 'ML', 'subGroupCode': 'DR', 'subCode': '0AX'}, {'@type': 'BrandAttribute', 'classification': 'SeatAssignment', 'inclusion': 'Included', 'groupCode': 'SA', 'subCode': '0B5'}, {'@type': 'BrandAttribute', 'classification': 'WiFi', 'inclusion': 'Included', 'groupCode': 'IE', 'subGroupCode': 'IT', 'subCode': '0CL'}, {'@type': 'BrandAttribute', 'classification': 'CheckedBag', 'inclusion': 'Included', 'groupCode': 'BG', 'subCode': '0CH'}, {'@type': 'BrandAttribute', 'classification': 'CarryOn', 'inclusion': 'Not Offered', 'groupCode': 'BG', 'subGroupCode': 'CY', 'subCode': '0MJ'}], 'AdditionalBrandAttribute': [{'@type': 'AdditionalBrandAttribute', 'groupCode': 'TS', 'subGroupCode': 'PO', 'subCode': '03P', 'Classification': 'Priority CheckIn', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'BF', 'subGroupCode': 'UE', 'subCode': '058', 'Classification': 'Upgrade', 'Inclusion': 'Chargeable'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'BF', 'subGroupCode': 'FR', 'subCode': '06R', 'Classification': 'Mileage Accrual', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'IE', 'subCode': '0B1', 'Classification': 'In Flight Entertainment', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'LG', 'subCode': '0BX', 'Classification': 'Lounge Access', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'TS', 'subGroupCode': 'PR', 'subCode': '0G6', 'Classification': 'Priority Boarding', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'TS', 'subGroupCode': 'PY', 'subCode': '0LF', 'Classification': 'Priority Baggage', 'Inclusion': 'Included'}], 'ImageURL': ['https://cdn.travelport.com/emirates/EK_general_medium_281051.JPG']}, {'@type': 'Brand', 'name': 'Business Special', 'tier': 6, 'shelfNumbers': [], 'code': 'BSSPCL', 'id': 'b3', 'Identifier': {'value': '1837061'}, 'BrandAttribute': [{'@type': 'BrandAttribute', 'classification': 'Refund', 'inclusion': 'Not Offered', 'groupCode': 'BF', 'subGroupCode': 'RF', 'subCode': '056'}, {'@type': 'BrandAttribute', 'classification': 'Rebooking', 'inclusion': 'Not Offered', 'groupCode': 'BF', 'subGroupCode': 'VC', 'subCode': '059'}, {'@type': 'BrandAttribute', 'classification': 'Meals', 'inclusion': 'Included', 'groupCode': 'ML', 'subGroupCode': 'DR', 'subCode': '0AX'}, {'@type': 'BrandAttribute', 'classification': 'SeatAssignment', 'inclusion': 'Not Offered', 'groupCode': 'SA', 'subCode': '0B5'}, {'@type': 'BrandAttribute', 'classification': 'WiFi', 'inclusion': 'Included', 'groupCode': 'IE', 'subGroupCode': 'IT', 'subCode': '0CL'}, {'@type': 'BrandAttribute', 'classification': 'CheckedBag', 'inclusion': 'Included', 'groupCode': 'BG', 'subCode': '0CH'}, {'@type': 'BrandAttribute', 'classification': 'CarryOn', 'inclusion': 'Not Offered', 'groupCode': 'BG', 'subGroupCode': 'CY', 'subCode': '0MJ'}], 'AdditionalBrandAttribute': [{'@type': 'AdditionalBrandAttribute', 'groupCode': 'TS', 'subGroupCode': 'PO', 'subCode': '03P', 'Classification': 'Priority CheckIn', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'BF', 'subGroupCode': 'UE', 'subCode': '058', 'Classification': 'Upgrade', 'Inclusion': 'Not Offered'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'BF', 'subGroupCode': 'FR', 'subCode': '06P', 'Classification': 'Mileage Accrual', 'Inclusion': 'Included'}, {' ...

# %% [markdown]
# Extracting Flight sequence

# %%
print(search_response["CatalogProductOfferingsResponse"]["ReferenceList"][0]["Flight"])
# Out:
rier': 'EK', 'number': '164', 'equipment': '77W', 'id': 's16', 'Departure': {'@type': 'DepartureDetail', 'terminal': '2', 'location': 'DUB', 'date': '2025-12-20', 'time': '20:50:00'}, 'Arrival': {'@type': 'ArrivalDetail', 'terminal': '3', 'location': 'DXB', 'date': '2025-12-21', 'time': '08:10:00'}, 'AvailabilitySourceCode': 'S'}, {'@type': 'FlightDetail', 'distance': 395, 'duration': 'PT1H35M', 'carrier': 'LH', 'number': '925', 'equipment': '32N', 'id': 's17', 'Departure': {'@type': 'DepartureDetail', 'terminal': '2', 'location': 'LHR', 'date': '2025-12-20', 'time': '08:30:00'}, 'Arrival': {'@type': 'ArrivalDetail', 'terminal': '1', 'location': 'FRA', 'date': '2025-12-20', 'time': '11:05:00'}, 'AvailabilitySourceCode': 'S'}, {'@type': 'FlightDetail', 'distance': 3015, 'duration': 'PT6H15M', 'carrier': 'EK', 'number': '46', 'equipment': '77W', 'id': 's18', 'Departure': {'@type': 'DepartureDetail', 'terminal': '2', 'location': 'FRA', 'date': '2025-12-20', 'time': '14:30:00'}, 'Arrival': {'@type': 'ArrivalDetail', 'terminal': '3', 'location': 'DXB', 'date': '2025-12-20', 'time': '23:45:00'}, 'Availabil ...

# %% [markdown]
# Extracting Product

# %%
print(search_response["CatalogProductOfferingsResponse"]["ReferenceList"][1]["Product"])
# Out:
# [{'@type': 'ProductAir', 'totalDuration': 'PT6H55M', 'id': 'p0', 'Quantity': 9, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's8'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'K', 'cabin': 'Economy', 'fareBasisCode': 'KHSOSGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'XOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b0'}}]}]}, {'@type': 'ProductAir', 'totalDuration': 'PT7H5M', 'id': 'p1', 'Quantity': 9, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's12'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'K', 'cabin': 'Economy', 'fareBasisCode': 'KHSOSGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'XOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b0'}}]}]}, {'@type': 'ProductAir', 'totalDuration': 'PT6H55M', 'id': 'p2', 'Quantity': 9, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's8'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'X', 'cabin': 'Economy', 'fareBasisCode': 'XHOWFGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'XOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b5'}}]}]}, {'@type': 'ProductAir', 'totalDuration': 'PT7H5M', 'id': 'p3', 'Quantity': 9, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's12'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'X', 'cabin': 'Economy', 'fareBasisCode': 'XHOWFGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'XOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b5'}}]}]}, {'@type': 'ProductAir', 'totalDuration': 'PT6H55M', 'id': 'p4', 'Quantity': 7, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's8'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'C', 'cabin': 'Business', 'fareBasisCode': 'COOWFGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'BOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b6'}}]}]}, {'@type': 'ProductAir', 'totalDuration': 'PT7H5M', 'id': 'p5', 'Quantity': 7, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's12'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'C', 'cabin': 'Business', 'fareBasisCode': 'COOWFGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'BOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b6'}}]}]}, {'@type': 'ProductAir', 'totalDuration': 'PT6H55M', 'id': 'p6', 'Quantity': 7, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's8'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'C', 'cabin': 'Business', 'fareBasisCode': 'ASSOSGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'FOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b7'}}]}]}, {'@type': 'ProductAir', 'totalDuration': 'PT7H5M', 'id': 'p7', 'Quantity': 4, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's12'}}], 'PassengerFlight': [{'@type': 'Passen ...

# %%
product = next((p for p in search_response["CatalogProductOfferingsResponse"]["ReferenceList"][1]["Product"] if p.get("id") == "p36"), None)
print(product)
# Out:
# {'@type': 'ProductAir', 'totalDuration': 'PT6H50M', 'id': 'p36', 'Quantity': 9, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's4'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'B', 'cabin': 'Economy', 'fareBasisCode': 'BHSOSGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'XOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b0'}}]}]}

# %% [markdown]
# Extracting Terms and Conditions

# %%
print(search_response["CatalogProductOfferingsResponse"]["ReferenceList"][3]["TermsAndConditions"])
# Out:
# [{'@type': 'TermsAndConditionsAir', 'id': 'T0', 'BaggageAllowance': [{'@type': 'BaggageAllowanceDetail', 'url': 'http://VIEWTRIP.TRAVELPORT.COM/BAGGAGEPOLICY/EK', 'passengerTypeCodes': ['ADT'], 'baggageType': 'FirstCheckedBag', 'validatingAirlineCode': 'EK', 'ProductRef': ['p0', 'p1'], 'BaggageItem': [{'@type': 'BaggageItem', 'includedInOfferPrice': 'Yes', 'soldByWeightInd': True, 'Measurement': [{'measurementType': 'Weight', 'unit': 'Kilograms', 'value': 30}], 'Text': 'CHGS MAY APPLY IF BAGS EXCEED TTL WT ALLOWANCE'}], 'SegmentSequenceList': [1]}, {'@type': 'BaggageAllowanceDetail', 'passengerTypeCodes': ['ADT'], 'baggageType': 'CarryOn', 'validatingAirlineCode': 'EK', 'ProductRef': ['p0', 'p1'], 'BaggageItem': [{'@type': 'BaggageItem', 'quantity': 1, 'includedInOfferPrice': 'Yes', 'soldByPieceInd': True, 'BaggageFee': {'code': 'EUR', 'approximateInd': True, 'value': 0}, 'Text': 'UPTO15LB/7KG AND UPTO45LI/115LCM'}], 'SegmentSequenceList': [1], 'Text': ['1P']}], 'ValidatingAirline': [{'@type': 'ValidatingAirline', 'ValidatingAirline': 'EK'}], 'PaymentTimeLimit': '2025-12-20T23:59:00Z', 'Penalties': [{'@type': 'Penalties', 'Change': [{'@type': 'ChangePermitted', 'penaltyTypes': ['Anytime'], 'PenaltyAppliesTo': 'PerTicket', 'Penalty': [{'@type': 'PenaltyAmount', 'Amount': {'code': 'EUR', 'minorUnit': 2, 'value': 85}}]}], 'Cancel': [{'@type': 'CancelPermitted', 'penaltyTypes': ['Anytime'], 'PenaltyAppliesTo': 'PerTicket', 'Penalty': [{'@type': 'PenaltyAmount', 'Amount': {'code': 'EUR', 'minorUnit': 2, 'value': 128}}]}], 'PassengerTypeCodes': ['ADT']}]}, {'@type': 'TermsAndConditionsAir', 'id': 'T1', 'BaggageAllowance': [{'@type': 'BaggageAllowanceDetail', 'url': 'http://VIEWTRIP.TRAVELPORT.COM/BAGGAGEPOLICY/EK', 'passengerTypeCodes': ['ADT'], 'baggageType': 'FirstCheckedBag', 'validatingAirlineCode': 'EK', 'ProductRef': ['p2', 'p3'], 'BaggageItem': [{'@type': 'BaggageItem', 'includedInOfferPrice': 'Yes', 'soldByWeightInd': True, 'Measurement': [{'measurementType': 'Weight', 'unit': 'Kilograms', 'value': 35}], 'Text': 'CHGS MAY APPLY IF BAGS EXCEED TTL WT ALLOWANCE'}], 'SegmentSequenceList': [1]}, {'@type': 'BaggageAllowanceDetail', 'passengerTypeCodes': ['ADT'], 'baggageType': 'CarryOn', 'validatingAirlineCode': 'EK', 'ProductRef': ['p2', 'p3'], 'BaggageItem': [{'@type': 'BaggageItem', 'quantity': 1, 'includedInOfferPrice': 'Yes', 'soldByPieceInd': True, 'BaggageFee': {'code': 'EUR', 'approximateInd': True, 'value': 0}, 'Text': 'UPTO15LB/7KG AND UPTO45LI/115LCM'}], 'SegmentSequenceList': [1], 'Text': ['1P']}], 'ValidatingAirline': [{'@type': 'ValidatingAirline', 'ValidatingAirline': 'EK'}], 'PaymentTimeLimit': '2025-12-20T23:59:00Z', 'Penalties': [{'@type': 'Penalties', 'Change': [{'@type': 'ChangePermitted', 'penaltyTypes': ['Anytime'], 'PenaltyAppliesTo': 'PerTicket', 'Penalty': [{'@type': 'PenaltyAmount', 'Amount': {'value': 0}}]}], 'Cancel': [{'@type': 'CancelPermitted', 'penaltyTypes': ['Anytime'], 'PenaltyAppliesTo': 'PerTicket', 'Penalty': [{'@type': 'PenaltyAmount', 'Amount': {'value': 0}}]}], 'PassengerTypeCodes': ['ADT']}]}, {'@type': 'TermsAndConditionsAir', 'id': 'T2', 'BaggageAllowance': [{'@type': 'BaggageAllowanceDetail', 'url': 'http://VIEWTRIP.TRAVELPORT.COM/BAGGAGEPOLICY/EK', 'passengerTypeCodes': ['ADT'], 'baggageType': 'FirstCheckedBag', 'validatingAirlineCode': 'EK', 'ProductRef': ['p4', 'p5'], 'BaggageItem': [{'@type': 'BaggageItem', 'includedInOfferPrice': 'Yes', 'soldByWeightInd': True, 'Measurement': [{'measurementType': 'Weight', 'unit': 'Kilograms', 'value': 40}], 'Text': 'CHGS MAY APPLY IF BAGS EXCEED TTL WT ALLOWANCE'}], 'SegmentSequenceList': [1]}, {'@type': 'BaggageAllowanceDetail', 'passengerTypeCodes': ['ADT'], 'baggageType': 'CarryOn', 'validatingAirlineCode': 'EK', 'ProductRef': ['p4', 'p5'], 'BaggageItem': [{'@type': 'BaggageItem', 'quantity': 2, 'includedInOfferPrice': 'Yes', 'soldByPieceInd': True, 'BaggageFee': {'code': 'EUR', 'approximateInd': True, 'value': 0}, 'Text': 'UPTO15LB/7KG AND UP ...

# %%
offers = search_response["CatalogProductOfferingsResponse"]["CatalogProductOfferings"]["CatalogProductOffering"]
my_offer = next((offer for offer in offers if offer.get("id") == "o5"), None)
print(my_offer)

brand = next((b for b in search_response["CatalogProductOfferingsResponse"]["ReferenceList"][2]["Brand"] if b.get("id") == "b0"), None)
print(brand)


flight = next((f for f in search_response["CatalogProductOfferingsResponse"]["ReferenceList"][0]["Flight"] if f.get("id") == "s4"), None)
print(flight)


product = next((p for p in search_response["CatalogProductOfferingsResponse"]["ReferenceList"][1]["Product"] if p.get("id") == "p36"), None)
print(product)

terms_and_conditions = next((t for t in search_response["CatalogProductOfferingsResponse"]["ReferenceList"][3]["TermsAndConditions"] if t.get("id") == "T17"), None)
print(terms_and_conditions)
# Out:
# {'@type': 'CatalogProductOffering', 'sequence': 1, 'id': 'o5', 'Departure': 'LHR', 'Arrival': 'DXB', 'Brand': [{'@type': 'BrandID', 'BrandRef': 'b0'}, {'@type': 'BrandID', 'BrandRef': 'b1'}, {'@type': 'BrandID', 'BrandRef': 'b2'}, {'@type': 'BrandID', 'BrandRef': 'b3'}, {'@type': 'BrandID', 'BrandRef': 'b4'}, {'@type': 'BrandID', 'BrandRef': 'b5'}, {'@type': 'BrandID', 'BrandRef': 'b6'}, {'@type': 'BrandID', 'BrandRef': 'b7'}, {'@type': 'BrandID', 'BrandRef': 'b8'}], 'ProductBrandOptions': [{'@type': 'ProductBrandOptions', 'flightRefs': ['s4'], 'ProductBrandOffering': [{'@type': 'ProductBrandOffering', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b0'}, 'Product': [{'@type': 'ProductID', 'productRef': 'p36'}], 'TermsAndConditions': {'@type': 'TermsAndConditionsID', 'termsAndConditionsRef': 'T17'}, 'CombinabilityCode': ['j18'], 'BestCombinablePrice': {'@type': 'BestCombinablePriceDetail', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 665, 'TotalTaxes': 256.22, 'TotalFees': 0, 'TotalPrice': 921.22, 'PriceBreakdown': [{'@type': 'PriceBreakdownAir', 'quantity': 1, 'requestedPassengerType': 'ADT', 'Amount': {'@type': 'Amount', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 665, 'Taxes': {'@type': 'TaxesDetail', 'TotalTaxes': 256.22, 'Tax': [{'taxCode': 'GB', 'value': 104}, {'taxCode': 'UB', 'value': 59.76}, {'taxCode': 'ZR', 'value': 1.17}, {'taxCode': 'YQ', 'value': 91.29}]}, 'Fees': {'@type': 'FeesDetail', 'TotalFees': 0}, 'Total': 921.22}, 'Surcharges': {'@type': 'SurchargesDetail', 'approximateInd': True, 'TotalSurcharges': 93, 'Surcharge': [{'currencyCode': 'EUR', 'purpose': 'Weekend Surcharge', 'decimalPlace': 2, 'value': 23}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 58}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 12}]}}]}, 'ContentSource': 'GDS'}, {'@type': 'ProductBrandOffering', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b5'}, 'Product': [{'@type': 'ProductID', 'productRef': 'p37'}], 'TermsAndConditions': {'@type': 'TermsAndConditionsID', 'termsAndConditionsRef': 'T18'}, 'CombinabilityCode': ['j19'], 'BestCombinablePrice': {'@type': 'BestCombinablePriceDetail', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 882, 'TotalTaxes': 256.22, 'TotalFees': 0, 'TotalPrice': 1138.22, 'PriceBreakdown': [{'@type': 'PriceBreakdownAir', 'quantity': 1, 'requestedPassengerType': 'ADT', 'Amount': {'@type': 'Amount', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 882, 'Taxes': {'@type': 'TaxesDetail', 'TotalTaxes': 256.22, 'Tax': [{'taxCode': 'GB', 'value': 104}, {'taxCode': 'UB', 'value': 59.76}, {'taxCode': 'ZR', 'value': 1.17}, {'taxCode': 'YQ', 'value': 91.29}]}, 'Fees': {'@type': 'FeesDetail', 'TotalFees': 0}, 'Total': 1138.22}, 'Surcharges': {'@type': 'SurchargesDetail', 'approximateInd': True, 'TotalSurcharges': 97, 'Surcharge': [{'currencyCode': 'EUR', 'purpose': 'Weekend Surcharge', 'decimalPlace': 2, 'value': 23}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 58}, {'currencyCode': 'EUR', 'purpose': 'Other', 'decimalPlace': 2, 'value': 16}]}}]}, 'ContentSource': 'GDS'}, {'@type': 'ProductBrandOffering', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b6'}, 'Product': [{'@type': 'ProductID', 'productRef': 'p38'}], 'TermsAndConditions': {'@type': 'TermsAndConditionsID', 'termsAndConditionsRef': 'T19'}, 'CombinabilityCode': ['j20'], 'BestCombinablePrice': {'@type': 'BestCombinablePriceDetail', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 3398, 'TotalTaxes': 780.84, 'TotalFees': 0, 'TotalPrice': 4178.84, 'PriceBreakdown': [{'@type': 'PriceBreakdownAir', 'quantity': 1, 'requestedPassengerType': 'ADT', 'Amount': {'@type': 'Amount', 'CurrencyCode': {'decimalPlace': 2, 'value': 'EUR'}, 'Base': 3398, 'Taxes': {'@type': 'TaxesDetail', 'TotalTaxes': 780.84, 'Tax': [{'taxCode': 'GB', 'value': 249.6}, {'taxCode': 'UB', 'value': 62.07}, {'taxCode': 'ZR', 'value': 1.17}, {'taxCode': 'YQ', 'value': 46 ...
# {'@type': 'Brand', 'name': 'Eco Flex', 'tier': 3, 'shelfNumbers': [], 'code': 'ECOFLEX', 'id': 'b0', 'Identifier': {'value': '1837064'}, 'BrandAttribute': [{'@type': 'BrandAttribute', 'classification': 'Refund', 'inclusion': 'Chargeable', 'groupCode': 'BF', 'subGroupCode': 'RF', 'subCode': '056'}, {'@type': 'BrandAttribute', 'classification': 'Rebooking', 'inclusion': 'Chargeable', 'groupCode': 'BF', 'subGroupCode': 'VC', 'subCode': '059'}, {'@type': 'BrandAttribute', 'classification': 'Meals', 'inclusion': 'Included', 'groupCode': 'ML', 'subGroupCode': 'DR', 'subCode': '0AX'}, {'@type': 'BrandAttribute', 'classification': 'SeatAssignment', 'inclusion': 'Chargeable', 'groupCode': 'SA', 'subCode': '0B5'}, {'@type': 'BrandAttribute', 'classification': 'WiFi', 'inclusion': 'Chargeable', 'groupCode': 'IE', 'subGroupCode': 'IT', 'subCode': '0CL'}, {'@type': 'BrandAttribute', 'classification': 'CheckedBag', 'inclusion': 'Included', 'groupCode': 'BG', 'subCode': '0CH'}, {'@type': 'BrandAttribute', 'classification': 'CarryOn', 'inclusion': 'Included', 'groupCode': 'BG', 'subGroupCode': 'CY', 'subCode': '0M3'}], 'AdditionalBrandAttribute': [{'@type': 'AdditionalBrandAttribute', 'groupCode': 'TS', 'subGroupCode': 'PO', 'subCode': '03P', 'Classification': 'Priority CheckIn', 'Inclusion': 'Not Offered'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'BF', 'subGroupCode': 'UE', 'subCode': '058', 'Classification': 'Upgrade', 'Inclusion': 'Chargeable'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'BF', 'subGroupCode': 'FR', 'subCode': '05V', 'Classification': 'Mileage Accrual', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'IE', 'subCode': '0B1', 'Classification': 'In Flight Entertainment', 'Inclusion': 'Included'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'LG', 'subCode': '0BX', 'Classification': 'Lounge Access', 'Inclusion': 'Not Offered'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'TS', 'subGroupCode': 'PR', 'subCode': '0G6', 'Classification': 'Priority Boarding', 'Inclusion': 'Not Offered'}, {'@type': 'AdditionalBrandAttribute', 'groupCode': 'TS', 'subGroupCode': 'PY', 'subCode': '0LF', 'Classification': 'Priority Baggage', 'Inclusion': 'Not Offered'}], 'ImageURL': ['https://cdn.travelport.com/emirates/EK_general_medium_281052.JPG']}
# {'@type': 'FlightDetail', 'distance': 3409, 'duration': 'PT6H50M', 'carrier': 'EK', 'number': '30', 'equipment': '388', 'id': 's4', 'Departure': {'@type': 'DepartureDetail', 'terminal': '3', 'location': 'LHR', 'date': '2025-12-20', 'time': '15:50:00'}, 'Arrival': {'@type': 'ArrivalDetail', 'terminal': '3', 'location': 'DXB', 'date': '2025-12-21', 'time': '02:40:00'}, 'AvailabilitySourceCode': 'Q'}
# {'@type': 'ProductAir', 'totalDuration': 'PT6H50M', 'id': 'p36', 'Quantity': 9, 'FlightSegment': [{'@type': 'FlightSegment', 'sequence': 1, 'Flight': {'@type': 'FlightID', 'FlightRef': 's4'}}], 'PassengerFlight': [{'@type': 'PassengerFlight', 'passengerQuantity': 1, 'passengerTypeCode': 'ADT', 'FlightProduct': [{'@type': 'FlightProduct', 'segmentSequence': [1], 'classOfService': 'B', 'cabin': 'Economy', 'fareBasisCode': 'BHSOSGB1', 'fareType': 'PublicFare', 'fareTypeCode': 'XOX', 'Brand': {'@type': 'BrandID', 'BrandRef': 'b0'}}]}]}
# {'@type': 'TermsAndConditionsAir', 'id': 'T17', 'BaggageAllowance': [{'@type': 'BaggageAllowanceDetail', 'url': 'http://VIEWTRIP.TRAVELPORT.COM/BAGGAGEPOLICY/EK', 'passengerTypeCodes': ['ADT'], 'baggageType': 'FirstCheckedBag', 'validatingAirlineCode': 'EK', 'ProductRef': ['p36'], 'BaggageItem': [{'@type': 'BaggageItem', 'includedInOfferPrice': 'Yes', 'soldByWeightInd': True, 'Measurement': [{'measurementType': 'Weight', 'unit': 'Kilograms', 'value': 30}], 'Text': 'CHGS MAY APPLY IF BAGS EXCEED TTL WT ALLOWANCE'}], 'SegmentSequenceList': [1]}, {'@type': 'BaggageAllowanceDetail', 'passengerTypeCodes': ['ADT'], 'baggageType': 'CarryOn', 'validatingAirlineCode': 'EK', 'ProductRef': ['p36'], 'BaggageItem': [{'@type': 'BaggageItem', 'quantity': 1, 'includedInOfferPrice': 'Yes', 'soldByPieceInd': True, 'BaggageFee': {'code': 'EUR', 'approximateInd': True, 'value': 0}, 'Text': 'UPTO15LB/7KG AND UPTO45LI/115LCM'}], 'SegmentSequenceList': [1], 'Text': ['1P']}], 'ValidatingAirline': [{'@type': 'ValidatingAirline', 'ValidatingAirline': 'EK'}], 'PaymentTimeLimit': '2025-12-20T23:59:00Z', 'Penalties': [{'@type': 'Penalties', 'Change': [{'@type': 'ChangePermitted', 'penaltyTypes': ['Anytime'], 'PenaltyAppliesTo': 'PerTicket', 'Penalty': [{'@type': 'PenaltyAmount', 'Amount': {'code': 'EUR', 'minorUnit': 2, 'value': 85}}]}], 'Cancel': [{'@type': 'CancelPermitted', 'penaltyTypes': ['Anytime'], 'PenaltyAppliesTo': 'PerTicket', 'Penalty': [{'@type': 'PenaltyAmount', 'Amount': {'code': 'EUR', 'minorUnit': 2, 'value': 128}}]}], 'PassengerTypeCodes': ['ADT']}]}

# %% [markdown]
# Extracting specifications for reservation

# %%
flightNumber = flight["number"]
print("flightNumber:", flightNumber)

carrier = flight["carrier"]
print("carrier:", carrier)

departureDate = flight["Departure"]["date"]
print("departureDate:", departureDate)
departureTime = flight["Departure"]["time"]
arrivalDate = flight["Arrival"]["date"]
arrivalTime = flight["Arrival"]["time"]
departure = flight["Departure"]["location"]
arrival = flight["Arrival"]["location"]
print("departureTime:", departureTime)
print("arrivalDate:", arrivalDate)
print("arrivalTime:", arrivalTime)
print("departure:", departure)
print("arrival:", arrival)


classOfService = product["PassengerFlight"][0]["FlightProduct"][0]["classOfService"]
cabin = product["PassengerFlight"][0]["FlightProduct"][0]["cabin"]
print("classOfService:", classOfService)
print("cabin:", cabin)

segmentSequence = product["PassengerFlight"][0]["FlightProduct"][0]["segmentSequence"][0]
print("segmentSequence:", segmentSequence)
brandTier = brand["tier"]
print("brandTier:", brandTier)
AvailabilitySourceCode = flight["AvailabilitySourceCode"]
print("AvailabilitySourceCode:", AvailabilitySourceCode)
ContentSource = my_offer["ProductBrandOptions"][0]["ProductBrandOffering"][0]["ContentSource"]
print("ContentSource:", ContentSource)
# Out:
# flightNumber: 30
# carrier: EK
# departureDate: 2025-12-20
# departureTime: 15:50:00
# arrivalDate: 2025-12-21
# arrivalTime: 02:40:00
# departure: LHR
# arrival: DXB
# classOfService: B
# cabin: Economy
# segmentSequence: 1
# brandTier: 3
# AvailabilitySourceCode: Q
# ContentSource: GDS

# %%
# flightNumber =  "2755"
# carrier = "AA"
# departureDate = "2025-06-28"
# departureTime = "06:49:00"
# arrivalDate = "2025-06-28"
# arrivalTime = "08:23:00"
# departure = "LHE"
# arrival = "DXB"
# classOfService = "Y"
# cabin = "Economy"
# segmentSequence = 1
# brandTier = "4"
# AvailabilitySourceCode = "Q"
# ContentSource = "GDS"

# %%
payload_dict= {
  "@type": "OfferQueryBuildFromProducts",
  "BuildFromProductsRequest": {
    "@type": "BuildFromProductsRequestAir",
    "PassengerCriteria": [
      {
        "@type": "PassengerCriteria",
        "number": num_passengers,
        "passengerTypeCode": passenger_type
      }
    ],
    "ProductCriteriaAir": [
      {
        "SpecificFlightCriteria": [
          {
            # "flightNumber": "2755",
            "flightNumber": flightNumber,
            # "carrier": "AA",
            "carrier": carrier,
            # "departureDate": "2025-06-28",
            "departureDate": departureDate,
            # "departureTime": "06:49:00",
            "departureTime": departureTime,
            # "arrivalDate": "2025-06-28",
            "arrivalDate": arrivalDate,
            # "arrivalTime": "08:23:00",
            "arrivalTime": arrivalTime,
            # "from": "LHE",
            "from": departure,
            "to": arrival,
            # "classOfService": "Y",
            "classOfService": classOfService,
            # "cabin": "Economy",
            "cabin": cabin,
            # "segmentSequence": 1,
            "segmentSequence": segmentSequence,
            # "brandTier": "4",
            "brandTier": brandTier,
            # "AvailabilitySourceCode": "Q",
            "AvailabilitySourceCode": AvailabilitySourceCode,
            # "ContentSource": "GDS"
            "ContentSource": ContentSource
          }
        ],
        "sequence": 1
      }
    ]
  }
}

reserve_payload = json.dumps(payload_dict)

# %%
url = "https://api.pp.travelport.com/11/air/book/airoffer/reservationworkbench/6f12e493-6f3f-4102-a76b-1119dee61d8d/offers/buildfromproducts"


headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
#   'trackingId': 'fdf6b395-9e8f-709b-b5b2-8fad2c4b3e0e',
  'trackingId': '6f12e493-6f3f-4102-a76b-1119dee61d8d',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Content-Version': '11',
  'Authorization': f'Bearer {token}'}

response = requests.request("POST", url, headers=headers, data=reserve_payload)

print(response.text)
# Out:
# {"OfferListResponse":{"@type":"OfferListResponse","OfferID":[{"@type":"OfferID","Identifier":{"authority":"Travelport","value":"d8f05c36-ae74-42c3-adf9-37f4653bb554"}}]}}

# %% [markdown]
# 3. Add Traveler

# %%
offer_id = "1e93095a-e6fd-4c9a-9e37-82bd6dd155b4"

# %%
import requests
import json

# %%
new_url = "https://api.pp.travelport.com/11/air/book/traveler/reservationworkbench/6f12e493-6f3f-4102-a76b-1119dee61d8d/travelers"

payload = json.dumps({
  "@type": "Traveler",
  "gender": "Male",
  "birthDate": "1986-11-11",
  "id": "trav_1",
  "passengerTypeCode": "ADT",
  "PersonName": {
    "@type": "PersonNameDetail",
    "Given": "Hummd",
    "Surname": "Bhai"
  },
  "Telephone": [
    {
      "@type": "Telephone",
      "countryAccessCode": "1",
      "phoneNumber": "212456121",
      "id": "4",
      "cityCode": "ORD",
      "role": "Home"
    }
  ],
  "Email": [
    {
      "value": "qtanwer@gmail.com"
    }
  ],
  "TravelDocument": [
    {
      "@type": "TravelDocumentDetail",
      "docNumber": "A123123",
      "docType": "Passport",
      "expireDate": "2035-10-16",
      "issueCountry": "US",
      "birthDate": "1986-11-11",
      "Gender": "Male",
      "PersonName": {
        "@type": "PersonName",
        "Given": "Hummd",
        "Surname": "Bhai"
      }
    }
  ]
})

# %%
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Content-Version': '11',
  'Authorization': f'Bearer {token}'
  }

response = requests.request("POST", new_url, headers=headers, data=payload)

print(response.text)
# Out:
# {"TravelerResponse":{"@type":"TravelerResponse","Traveler":{"@type":"TravelerIdentifier","Identifier":{"value":"f6b80949-8fe2-4172-96be-ee2a77ad47cf"}}}}

# %%
after_adding_passenger_response = "f6b80949-8fe2-4172-96be-ee2a77ad47cf"

# %% [markdown]
# ### Commit reservation

# %%
import requests
import json

# %%
url = "https://api.pp.travelport.com/11/air/book/reservation/reservations/6f12e493-6f3f-4102-a76b-1119dee61d8d"

payload = json.dumps({
  "@type": "ReservationQueryCommitReservation"
})

# %%
headers = {
  'Accept': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Content-Version': '11',
  'Content-Type': 'application/json',
  'Authorization': f'Bearer {token}'
}
response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"ReservationResponse":{"@type":"ReservationResponse","Reservation":{"@type":"Reservation","Offer":[{"@type":"Offer","id":"offer_1","Identifier":{"authority":"Travelport","value":"47b71be1-dfcd-44b6-8a89-4ffebea07b81"},"ContentSource":"GDS","Product":[{"@type":"ProductAir","id":"product_1","FlightSegment":[{"@type":"FlightSegment","id":"FlightSegment_01","sequence":1,"Flight":{"@type":"FlightDetail","duration":"PT10H50M","carrier":"EK","number":"30","id":"Flight_01","Departure":{"@type":"Departure","location":"LHR","date":"2025-12-20","time":"15:50:00"},"Arrival":{"@type":"Arrival","location":"DXB","date":"2025-12-21","time":"02:40:00"},"AvailabilitySourceCode":"Q"}}],"PassengerFlight":[{"@type":"PassengerFlight","passengerQuantity":1,"passengerTypeCode":"ADT","FlightProduct":[{"@type":"FlightProduct","segmentSequence":[1],"classOfService":"B","cabin":"Economy"}]}]}],"Price":{"@type":"PriceDetail","id":"PriceDetail_1","CurrencyCode":{"value":"EUR"},"Base":665,"TotalTaxes":256.22,"TotalFees":0,"TotalPrice":921.22,"PriceBreakdown":[{"@type":"PriceBreakdownAir","quantity":1,"requestedPassengerType":"ADT","Amount":{"@type":"Amount","currencySource":"Charged","approximateInd":true,"CurrencyCode":{"decimalPlace":2,"value":"EUR"},"Base":665,"Taxes":{"@type":"TaxesDetail","TotalTaxes":256.22,"Tax":[{"currencyCode":"EUR","taxCode":"GB","value":104},{"currencyCode":"EUR","taxCode":"UB","value":59.76},{"currencyCode":"EUR","taxCode":"ZR","value":1.17},{"currencyCode":"EUR","taxCode":"YQ","value":91.29}]},"Total":921.22},"FiledAmount":{"currencyCode":"GBP","decimalPlace":2,"value":575}}]},"TermsAndConditionsFull":[{"@type":"TermsAndConditionsFullAir","Identifier":{"authority":"Travelport","value":"91fd9540-42d9-45bc-8288-2246447f1e7e"}},{"@type":"TermsAndConditionsFullAir","ExpiryDate":"2025-12-20T23:59:00Z","PaymentTimeLimit":"2025-12-20T23:59:00Z"}]}],"Traveler":[{"@type":"Traveler","birthDate":"1986-11-11","gender":"Male","passengerTypeCode":"ADT","id":"travelerRefId_1","Identifier":{"authority":"Travelport","value":"020a5070-f429-49ec-bd70-b3044e0e31ec"},"PersonName":{"@type":"PersonName","Given":"HUMMD","Surname":"BHAI"},"Telephone":[{"@type":"TelephoneDetail","countryAccessCode":"1","phoneNumber":"212456121","id":"telephone_1","cityCode":"ORD","role":"Home"}],"Email":[{"emailType":"TO","value":"qtanwer@gmail.com"}],"TravelDocument":[{"@type":"TravelDocumentDetail","birthDate":"1986-11-11","Gender":"Male","PersonName":{"@type":"PersonName","Given":"HUMMD","Surname":"BHAI"}},{"@type":"TravelDocumentDetail","docNumber":"A123123","docType":"Passport","expireDate":"2035-10-16","issueCountry":"US","birthDate":"1986-11-11","Gender":"Male","PersonName":{"@type":"PersonName","Given":"HUMMD","Surname":"BHAI"}}]}],"Receipt":[{"@type":"ReceiptConfirmation","Identifier":{"authority":"Travelport","value":"1eae72c1-556b-4ef1-8355-4c4ad13aa692"},"Confirmation":{"@type":"ConfirmationHold","Locator":{"source":"1G","creationDate":"2025-10-17","value":"D72LVG"},"OfferStatus":{"@type":"OfferStatusAir","StatusAir":[{"flightRefs":["Flight_01"],"code":"HK","value":"Confirmed"}]}}},{"@type":"ReceiptConfirmation","Identifier":{"authority":"Travelport","value":"a298cf4e-4f1a-463e-8fa3-541daea2a502"},"Confirmation":{"@type":"ConfirmationHold","Locator":{"source":"EK","value":"HZTM5J"}}}],"SpecialService":[{"@type":"SpecialService","id":"SpecialService_1","Identifier":{"authority":"Travelport","value":"5369b47f-7a74-4d22-bd0c-e21716438a64"},"AppliesTo":{"@type":"AppliesToOfferProductSegment","OfferIdentifier":{"offerRef":"offer_1"},"ProductIdentifier":{"productRef":"product_1"},"SegmentSequenceList":[1]},"Status":{"value":"Confirmed"},"TravelerIdentifier":{"TravelerRef":"travelerRefId_1","Identifier":{"authority":"Travelport","value":"020a5070-f429-49ec-bd70-b3044e0e31ec"}},"Quantity":1,"FreeText":"EK/ECOFLEX","SSRCode":"BFFF"}],"ReservationDisplaySequence":{"@type":"ReservationDisplaySequence","DisplaySequence":[{"@type":"DisplaySequence","displaySequence":1," ...

# %%
# save response to a json file
with open("final_reservation_response.json", "w") as json_file:
    json.dump(response.json(), json_file)

# %% [markdown]
# ### Ticket

# %% [markdown]
# 1. Initiate workbench

# %%
import requests
import json
import os

# %%
pnr_locator = "D72LVG"

# %%
url = f"https://api.pp.travelport.com/11/air/book/session/reservationworkbench/buildfromlocator?Locator={pnr_locator}"

payload = ""
headers = {
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Accept': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# 1012100 - Credentials invalid or missing.

# %%
workbench_token = ""

# %% [markdown]
# 2. Add Form of Payment

# %%
import requests
import json

url = "https://api.pp.travelport.com/11/air/payment/reservationworkbench//formofpayment"

payload = json.dumps({
  "@type": "FormOfPaymentPaymentCard",
  "id": "formOfPayment_1",
  "FormOfPaymentRef": "formOfPayment_1",
  "PaymentCard": {
    "@type": "PaymentCardDetail",
    "id": "paymentCard_4",
    "expireDate": "1228",
    "CardType": "Credit",
    "CardCode": "VI",
    "CardHolderName": "JANE DOE",
    "approvalCode": "123456",
    "CardNumber": {
      "@type": "CardNumber",
      "PlainText": "4987654321098769"
    },
    "SeriesCode": {
      "PlainText": "123"
    }
  }
})
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Content-Version': '11',
  'Authorization': f'Bearer {token}'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %% [markdown]
# 3. Apply Payment

# %%
import requests
import json

# %%
# url = "https://{{baseURL}}/{{version}}/air/paymentoffer/reservationworkbench/{1546cc57-c5c3-4670-b555-fed35dd69ddf}/payments"
url = f"https://api.pp.travelport.com/11/air/paymentoffer/reservationworkbench/{workbench_token}/payments"


payload = json.dumps({
  "@type": "Payment",
  "id": "payment_1",
  "Identifier": {
    "authority": "Travelport",
    "value": "A0656EFF-FAF4-456F-B061-0161008D6A5E"
  },
  "Amount": {
    "code": "USD",
    "minorUnit": 2,
    "currencySource": "Charged",
    "value": 943.6
  },
  "FormOfPaymentIdentifier": {
    "id": "formOfPayment_1",
    "FormOfPaymentRef": "formOfPayment_1",
    "Identifier": {
      "authority": "Travelport",
      "value": "1546cc57-c5c3-4670-b555-fed35dd69ddf"
    }
  },
  "OfferIdentifier": [
    {
      "id": "offer_1",
      "offerRef": "offer_1",
      "Identifier": {
        "authority": "Travelport",
        "value": "9829d223-66dc-4590-8a8e-66a1669f8b00"
      }
    }
  ]
})
headers = {
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Accept': 'application/json',
  'Content-Version': '11'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %% [markdown]
# 4. Review before genrating

# %%
import requests
import json

# %%
# url = "https://{{baseURL}}/{{version}}/air/book/session/reservationworkbench/1546cc57-c5c3-4670-b555-fed35dd69ddf"

url = f"https://api.pp.travelport.com/11/air/book/session/reservationworkbench/{workbench_token}"


payload = {}
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP")
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)

# %% [markdown]
# 5. Ticket Genration

# %%
url = f"https://api.pp.travelport.com/11/air/book/reservation/reservations/{workbench_token}"

payload = json.dumps({
  "@type": "ReservationQueryCommitReservation"
})
headers = {
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'Authorization': f'Bearer {token}',
    'Content-Version': '11'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %% [markdown]
# 6. Review

# %%
url = f"https://api.pp.travelport.com/11/air/book/reservation/reservations/{pnr_locator}"

payload = {}
headers = {
  'Accept': 'application/json',
  'Content-Type': 'application/json',
  'XAUTH_TRAVELPORT_ACCESSGROUP': os.getenv("TRAVELPORT_ACCESS_GROUP"),
  'Authorization': f'Bearer {token}',
  'Content-Version': '11'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
